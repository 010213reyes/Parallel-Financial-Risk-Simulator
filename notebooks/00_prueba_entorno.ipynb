# %%
import sys

print("Python ejecutándose desde:")
print(sys.executable)
# Out:
# Python ejecutándose desde:
# c:\Users\REYES\OneDrive\Desktop\9noSemestre\programacion paralela\analisis riesgo montecarlo\.venv\Scripts\python.exe

# %%
import numpy as np
import pandas as pd
import matplotlib
import sys

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
# Out:
# Python: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# NumPy: 2.5.2
# Pandas: 3.0.5
# Matplotlib: 3.11.1

# %%
import numpy as np

data = np.array([10, 20, 30, 40, 50])

print("Datos:", data)
print("Promedio:", data.mean())
# Out:
# Datos: [10 20 30 40 50]
# Promedio: 30.0

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 3, 5, 4]

plt.plot(x, y)
plt.title("Prueba del entorno")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
